# %% [markdown]
# # Schiefe Ebene mit Reibung

# %% [markdown]
# Technische Universität Berlin, Straße des 17. Juni 135, 10623 Berlin, Deutschland
#
# ---
#
# **Dovat Atayev** (Kurs 348T)
#
# E-mail: dovat.atayev2019@campus.tu-berlin.de
#
# **Anna Chapak** (Kurs 348T)
#
# E-mail: anna.chapak@campus.tu-berlin.de
#
# **Allan Zea** (Kurs 348T)
#
# E-mail: zealobo@campus.tu-berlin.de
#
# ---

# %% [markdown]
# ### Handy-Kalibrierung
#
#
#
# ---

# %% [markdown]
# ### Haftreibung
#
# ---

# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt

tabelle1 = pandas.read_csv('Daten/reibungebene/Versuch 1.1.csv')
tabelle2 = pandas.read_csv('Daten/reibungebene/Versuch 1.2.csv')
tabelle3 = pandas.read_csv('Daten/reibungebene/Versuch 1.3.csv')
tabelle4 = pandas.read_csv('Daten/reibungebene/Versuch 1.4.csv')
tabelle5 = pandas.read_csv('Daten/reibungebene/Versuch 1.5.csv')
tabelle6 = pandas.read_csv('Daten/reibungebene/Versuch 1.6.csv')

print(tabelle1)
# Out:
#       Time (s)  Acceleration x (m/s^2)  Acceleration y (m/s^2)  \
# 0     0.000000                0.093994                0.137039
# 1     0.003998                0.096390                0.144226
# 2     0.008026                0.086823                0.149002
# 3     0.012054                0.086823                0.144226
# 4     0.016083                0.093994                0.141830
# ...        ...                     ...                     ...
# 1503  6.019899                0.060486                2.691650
# 1504  6.023897                0.060486                2.708405
# 1505  6.027926                0.058090                2.694046
# 1506  6.031923                0.050903                2.684464
# 1507  6.035921                0.046112                2.674896
#
#       Acceleration z (m/s^2)  Absolute acceleration (m/s^2)
# 0                   9.584137                       9.585577
# 1                   9.584137                       9.585707
# 2                   9.598495                       9.600045
# 3                   9.603287                       9.604762
# 4                   9.603287                       9.604794
# ...                      ...                            ...
# 1503                9.263306                       9.646630
# 1504                9.289642                       9.676599
# 1505                9.299225                       9.681779
# 1506                9.275284                       9.656077
# 1507                9.263306                       9.641889
#
# [1508 rows x 5 columns]

# %%
plt.plot(tabelle1["Acceleration x (m/s^2)"], 'g-')
plt.plot(tabelle1["Acceleration y (m/s^2)"], 'r-')
plt.plot(tabelle1["Acceleration z (m/s^2)"], 'b-')

# %%
plt.plot(tabelle2["Acceleration x (m/s^2)"], 'g-')
plt.plot(tabelle2["Acceleration y (m/s^2)"], 'r-')
plt.plot(tabelle2["Acceleration z (m/s^2)"], 'b-')

# %%
plt.plot(tabelle3["Acceleration x (m/s^2)"], 'g-')
plt.plot(tabelle3["Acceleration y (m/s^2)"], 'r-')
plt.plot(tabelle3["Acceleration z (m/s^2)"], 'b-')

# %%
plt.plot(tabelle4["Acceleration x (m/s^2)"], 'g-')
plt.plot(tabelle4["Acceleration y (m/s^2)"], 'r-')
plt.plot(tabelle4["Acceleration z (m/s^2)"], 'b-')

# %%
plt.plot(tabelle5["Acceleration x (m/s^2)"], 'g-')
plt.plot(tabelle5["Acceleration y (m/s^2)"], 'r-')
plt.plot(tabelle5["Acceleration z (m/s^2)"], 'b-')

# %%
plt.plot(tabelle6["Acceleration x (m/s^2)"], 'g-')
plt.plot(tabelle6["Acceleration y (m/s^2)"], 'r-')
plt.plot(tabelle6["Acceleration z (m/s^2)"], 'b-')

# %% [markdown]
# ### Gleitreibung
#
#
# ---
