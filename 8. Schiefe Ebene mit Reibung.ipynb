# %% [markdown]
# # Schiefe Ebene mit Reibung

# %% [markdown]
# Technische Universität Berlin, Straße des 17. Juni 135, 10623 Berlin, Deutschland
#
# ---
#
# **Dovat Atayev** (Kurs 348T)
#
# E-mail: dovat.atayev2019@campus.tu-berlin.de
#
# **Anna Chapak** (Kurs 348T)
#
# E-mail: anna.chapak@campus.tu-berlin.de
#
# **Allan Zea** (Kurs 348T)
#
# E-mail: zealobo@campus.tu-berlin.de
#
# ---

# %% [markdown]
# ### Beschreibung
#
# Für dieses Experiment verwendeten wir ein Handy als Messinstrument und das Programm PHYPHOX, welches die Beschleunigungssensoren auslesen kann. Als schiefe Ebene nutzten wir ein Buch (siehe **Abb. 1**) mit einer harten und glatten Oberfläche und den Dimensionen $26,5\textrm{ cm}\times 20,0\textrm{ cm}$. Im Vorexperiment benutzten wir die App [Bubble Level, Spirit Level](https://play.google.com/store/apps/details?id=org.nixgame.bubblelevel) (einen Neigungsmesser), um sicherzustellen, dass das Handy möglichst ohne Rotation und Störungen herunterrutschte.
# Dies erlaubte uns, einen Aufbau zu finden, der stabil war und einen guten „Anschlag“ zur Zeitmessung bot.
#
# ![](https://raw.githubusercontent.com/allgebrist/studienkolleg-physik-praktikum/master/Bilder/8.1.jpg)
#
# ---

# %% [markdown]
# ### 1. Haftreibung
#
# Zur Messung der Haftreibung stellten wir das Messgerät auf das Buch, und erhöhten langsam und gleichmäßig den
# Winkel zwischen dem Buch und der horizontalen Ebene, bis es anfing zu rutschen. Das Experiment wurde 6 Mal zur Bestimmung des Wertes und des wahrscheinlichen Fehlers der Haftreibung $\mu_H$ wiederholt. Wir kennen aus der Theorie, dass für den Haftreibungskoeffizienten gilt
#
# \begin{equation}
#     \mu_H=\tan\alpha_H,
# \end{equation}
#
# wobei $\alpha_H$ der Winkel beim Losrutschen darstellt.
#
# Eine erste Abschätzung dieses Grenzwinkels, $\alpha_{H_0}$, konnte bereits im Vorexperiment mit dem Neigungsmesser gemessen werden: nach 10 Messungen stellte sich heraus, dass $\overline{\alpha_{H_0}}+\Delta\overline{\alpha_{H_0}} = (15,6 \pm 0,1)^{\textrm{o}}$. Der tatsächliche Wert von $\alpha_H$ ließ sich schnell durch eine Auswertung der Komponenten des Beschleunigungsvektors $(a_x, a_y, a_z)$ bezüglich der Senkrechten ermitteln (siehe **Abb. 2**). Dafür war aber durchaus wichtig zu verstehen, wie die verschiedene Bereiche der Tabellen mit der Beschleunigung des Messgeräts zusammenhängen (siehe die 3. Abbildung von [2]).
#
# ![](https://raw.githubusercontent.com/allgebrist/studienkolleg-physik-praktikum/master/Bilder/8.2.jpg)
#
# Der Winkel $\alpha_H$ ist gleich dem Winkel $\psi$ zwischen der $Y$-Achse des Messgeräts und dem Gravitationssystem [1]. Der Winkel der schiefen Ebene kann man unter Verwendung der Beschleunigungsmessungen $a_x$, $a_y$ und $a_z$ im Ruhezustand bzw. beim Losrutschen wie folgt berechnen:
#
# \begin{equation}
#     \alpha_H = \psi = \arctan\left(\frac{a_y}{\sqrt{a_x^2+a_z^2}}\right).
# \end{equation}
#
# Mithilfe dieser Gleichung erstellten wir eine neue Spalte in unseren Tabellen, um die Änderung des Winkels im Laufe des Experiments nachvollziehen zu können. Ein Blick auf unsere Messungen finden Sie weiter unten im Dokument.
#
# Der wahrscheinliche Fehler von $\mu_H$ kann nach Gauß folgendermaßen bestimmt werden:
#
# \begin{aligned}
#     \Delta\mu_H &= \sqrt{\left[\frac{\partial}{\partial a_x}\left(\frac{a_y}{\sqrt{a_x^2+a_z^2}}\right)\cdot\Delta a_x\right]^2
#                             + \left[\frac{\partial}{\partial a_y}\left(\frac{a_y}{\sqrt{a_x^2+a_z^2}}\right)\cdot\Delta a_y\right]^2
#                             + \left[\frac{\partial}{\partial a_z}\left(\frac{a_y}{\sqrt{a_x^2+a_z^2}}\right)\cdot\Delta a_z\right]^2 } \\
#                    &= \sqrt{\left(-\frac{a_x a_y}{(a_x^2+a_z^2)^{3/2}}\cdot\Delta a_x\right)^2
#                             + \left(\frac{1}{\sqrt{a_x^2+a_z^2}}\cdot\Delta a_y\right)^2
#                             + \left(-\frac{a_y a_z}{(a_x^2+a_z^2)^{3/2}}\cdot\Delta a_z\right)^2 }.
# \end{aligned}
#
# ---

# %%
import math
import pandas
import numpy as np
import matplotlib.pyplot as plt

tabelle1 = pandas.read_csv('Daten/reibungebene/Versuch 1.1.csv')
tabelle2 = pandas.read_csv('Daten/reibungebene/Versuch 1.2.csv')
tabelle3 = pandas.read_csv('Daten/reibungebene/Versuch 1.3.csv')
tabelle4 = pandas.read_csv('Daten/reibungebene/Versuch 1.4.csv')
tabelle5 = pandas.read_csv('Daten/reibungebene/Versuch 1.5.csv')
tabelle6 = pandas.read_csv('Daten/reibungebene/Versuch 1.6.csv')

print(tabelle1)
# Out:
#       Time (s)  Acceleration x (m/s^2)  Acceleration y (m/s^2)  \
# 0     0.000000                0.093994                0.137039
# 1     0.003998                0.096390                0.144226
# 2     0.008026                0.086823                0.149002
# 3     0.012054                0.086823                0.144226
# 4     0.016083                0.093994                0.141830
# ...        ...                     ...                     ...
# 1194  4.782381                0.565659                5.157684
# 1195  4.786379                0.338211                4.626160
# 1196  4.790407                0.153854                4.369980
# 1197  4.794405                0.070053                4.504059
# 1198  4.798403                0.048508                4.530396
#
#       Acceleration z (m/s^2)  Absolute acceleration (m/s^2)  Angle (deg)
# 0                   9.584137                       9.585577     0.819151
# ...

# %%
fig, axs = plt.subplots(2, 3, figsize = (16, 6))

axs[0][0].plot(tabelle1["Time (s)"], tabelle1["Acceleration x (m/s^2)"], 'g-', label = 'ax')
axs[0][0].plot(tabelle1["Time (s)"], tabelle1["Acceleration y (m/s^2)"], 'r-', label = 'ay')
axs[0][0].plot(tabelle1["Time (s)"], tabelle1["Acceleration z (m/s^2)"], 'b-', label = 'az')
legend = axs[0][0].legend(loc = 'upper left', shadow = True, fontsize = 'small')

axs[0][1].plot(tabelle2["Time (s)"], tabelle2["Acceleration x (m/s^2)"], 'g-', label = 'ax')
axs[0][1].plot(tabelle2["Time (s)"], tabelle2["Acceleration y (m/s^2)"], 'r-', label = 'ay')
axs[0][1].plot(tabelle2["Time (s)"], tabelle2["Acceleration z (m/s^2)"], 'b-', label = 'az')
legend = axs[0][1].legend(loc = 'center left', shadow = True, fontsize = 'small')

axs[0][2].plot(tabelle3["Time (s)"], tabelle3["Acceleration x (m/s^2)"], 'g-', label = 'ax')
axs[0][2].plot(tabelle3["Time (s)"], tabelle3["Acceleration y (m/s^2)"], 'r-', label = 'ay')
axs[0][2].plot(tabelle3["Time (s)"], tabelle3["Acceleration z (m/s^2)"], 'b-', label = 'az')
legend = axs[0][2].legend(loc = 'center left', shadow = True, fontsize = 'small')

axs[1][0].plot(tabelle4["Time (s)"], tabelle4["Acceleration x (m/s^2)"], 'g-', label = 'ax')
axs[1][0].plot(tabelle4["Time (s)"], tabelle4["Acceleration y (m/s^2)"], 'r-', label = 'ay')
axs[1][0].plot(tabelle4["Time (s)"], tabelle4["Acceleration z (m/s^2)"], 'b-', label = 'az')
legend = axs[1][0].legend(loc = 'upper left', shadow = True, fontsize = 'small')

axs[1][1].plot(tabelle5["Time (s)"], tabelle5["Acceleration x (m/s^2)"], 'g-', label = 'ax')
axs[1][1].plot(tabelle5["Time (s)"], tabelle5["Acceleration y (m/s^2)"], 'r-', label = 'ay')
axs[1][1].plot(tabelle5["Time (s)"], tabelle5["Acceleration z (m/s^2)"], 'b-', label = 'az')
legend = axs[1][1].legend(loc = 'upper left', shadow = True, fontsize = 'small')

axs[1][2].plot(tabelle6["Time (s)"], tabelle6["Acceleration x (m/s^2)"], 'g-', label = 'ax')
axs[1][2].plot(tabelle6["Time (s)"], tabelle6["Acceleration y (m/s^2)"], 'r-', label = 'ay')
axs[1][2].plot(tabelle6["Time (s)"], tabelle6["Acceleration z (m/s^2)"], 'b-', label = 'az')
legend = axs[1][2].legend(loc = 'upper left', shadow = True, fontsize = 'small')

for ax in axs.flat:
    ax.set(xlabel = 'Zeit (s)', ylabel = 'Beschleunigung ($m/s^2$)')

# %% [markdown]
# ---
#
# **Bemerkung:** Für die Bestimmung von $\alpha_H$ zogen wir ausschließlich jene Messungen in Betracht, die aufgenommen wurden, als das Messgerät begann, herunterzurutschen. Dies geschah ungefähr in dem Bereich zwischen der 600. und der 1000. Messung. Hier stabilisierte sich die Änderung des Winkels und wich nicht zu stark von unserer ersten Schätzung ab. Dies wird in der nachfolgenden Abbildung gezeigt.

# %%
x = np.linspace(0, 1200)
plt.plot(x, [15.6]*50, 'r--', label = '$\\alpha_{H_0}$ = 15,6')
plt.legend(loc = 'upper left', shadow = True, fontsize = 'large')

plt.plot(tabelle1["Angle (deg)"], alpha = 0.6)
plt.plot(tabelle2["Angle (deg)"], alpha = 0.6)
plt.plot(tabelle3["Angle (deg)"], alpha = 0.6)
plt.plot(tabelle4["Angle (deg)"], alpha = 0.6)
plt.plot(tabelle5["Angle (deg)"], alpha = 0.6)
plt.plot(tabelle6["Angle (deg)"], alpha = 0.6)

# %%
winkel = ( np.mean(tabelle1["Angle (deg)"][600:1000]) + 
           np.mean(tabelle2["Angle (deg)"][600:1000]) + 
           np.mean(tabelle3["Angle (deg)"][600:1000]) + 
           np.mean(tabelle4["Angle (deg)"][600:1000]) + 
           np.mean(tabelle5["Angle (deg)"][600:1000]) + 
           np.mean(tabelle6["Angle (deg)"][600:1000])) / 6

winkel
# Out:
# 15.97632967365056

# %%
haftreibung = math.tan(winkel * (math.pi / 180))
haftreibung
# Out:
# 0.28629834520779923

# %%
ax_mittel = np.mean(tabelle1["Acceleration x (m/s^2)"][600:1000])
ay_mittel = np.mean(tabelle1["Acceleration y (m/s^2)"][600:1000])
az_mittel = np.mean(tabelle1["Acceleration z (m/s^2)"][600:1000])

ax_std = np.std(tabelle1["Acceleration x (m/s^2)"][600:1000], ddof = 1)
ay_std = np.std(tabelle1["Acceleration y (m/s^2)"][600:1000], ddof = 1)
az_std = np.std(tabelle1["Acceleration z (m/s^2)"][600:1000], ddof = 1)

ax_err = ax_std / math.sqrt(400)
ay_err = ay_std / math.sqrt(400)
az_err = az_std / math.sqrt(400)

wahr_fehler = math.sqrt( (((ax_mittel*ay_mittel)/(ax_mittel**2 + az_mittel**2)**(3/2))*ax_err)**2 
                        + ((1/(ax_mittel**2 + az_mittel**2)**(1/2))*ay_err)**2 
                        + (((ay_mittel*az_mittel)/(ax_mittel**2 + az_mittel**2)**(3/2))*az_err)**2 )

# %%
wahr_fehler
# Out:
# 0.0016951518851909268

# %% [markdown]
# **Nach unserer Analyse lässt sich also feststellen, dass $\mu_H\pm\Delta\mu_H = 0,2863 \pm 0,0017$.**
#
# ---

# %% [markdown]
# ### 2. Gleitreibung
#
# Für die Durchführung dieses Experiments nahmen wir eine Beobachtung von [2] in Anspruch (siehe Gleichung (A.10)): dass durch einfaches Bestimmen von $a_y/g$ für nur zwei verschiedene Winkel und grafische Extrapolation auf den Winkel, bei dem $a_y/g = 0$ ist, $\mu_G$ bestimmt werden kann. Diese Winkel berechneten wir aus der Datenmenge durch eine Bereichunterteilung der Beschleunigung in $y$-Richtung, analog zur letzen Aufgabe. Obwohl wir die Messung für vier verschiedenen $\psi > \alpha_H$ durchführten, berücksichtigten wir aufgrund ihrer Qualität nur die ersten zwei für die Auswertung in Abschnitt 2.1.
#
# **Beobachtung.** Die Beschleunigungen $a_y$ bekommt man nach [2], indem man die Beschleunigung des Handys im Ruhezustand von der Maximalbeschleunigung subtrahiert.
#
# ---

# %%
tabelle211 = pandas.read_csv('Daten/reibungebene/Versuch 2 Winkel 1.1.csv')
tabelle212 = pandas.read_csv('Daten/reibungebene/Versuch 2 Winkel 1.2.csv')
tabelle213 = pandas.read_csv('Daten/reibungebene/Versuch 2 Winkel 1.3.csv')
tabelle214 = pandas.read_csv('Daten/reibungebene/Versuch 2 Winkel 1.4.csv')
tabelle215 = pandas.read_csv('Daten/reibungebene/Versuch 2 Winkel 1.5.csv')
tabelle216 = pandas.read_csv('Daten/reibungebene/Versuch 2 Winkel 1.6.csv')

winkel_1 = np.mean([np.mean(tabelle211["Angle (deg)"][0:20]), 
                    np.mean(tabelle212["Angle (deg)"][0:20]), 
                    np.mean(tabelle213["Angle (deg)"][0:20]), 
                    np.mean(tabelle214["Angle (deg)"][0:20]), 
                    np.mean(tabelle215["Angle (deg)"][0:20]), 
                    np.mean(tabelle216["Angle (deg)"][0:20])])

beschleunigung_y1 = np.mean([max(tabelle211["Acceleration y (m/s^2)"])-np.mean(tabelle211["Acceleration y (m/s^2)"][0:20]), 
                             max(tabelle212["Acceleration y (m/s^2)"])-np.mean(tabelle212["Acceleration y (m/s^2)"][0:20]),
                             max(tabelle213["Acceleration y (m/s^2)"])-np.mean(tabelle213["Acceleration y (m/s^2)"][0:20]),
                             max(tabelle214["Acceleration y (m/s^2)"])-np.mean(tabelle214["Acceleration y (m/s^2)"][0:20]),
                             max(tabelle215["Acceleration y (m/s^2)"])-np.mean(tabelle215["Acceleration y (m/s^2)"][0:20]),
                             max(tabelle216["Acceleration y (m/s^2)"])-np.mean(tabelle216["Acceleration y (m/s^2)"][0:20])])

print('Winkel: ', winkel_1)
print('Beschleunigung in y-Richtung: ', beschleunigung_y1)

plt.plot(tabelle211["Acceleration y (m/s^2)"], alpha = 0.6)
plt.plot(tabelle212["Acceleration y (m/s^2)"], alpha = 0.6)
plt.plot(tabelle213["Acceleration y (m/s^2)"], alpha = 0.6)
plt.plot(tabelle214["Acceleration y (m/s^2)"], alpha = 0.6)
plt.plot(tabelle215["Acceleration y (m/s^2)"], alpha = 0.6)
plt.plot(tabelle216["Acceleration y (m/s^2)"], alpha = 0.6)
# Out:
# Winkel:  16.463505958656285
# Beschleunigung in y-Richtung:  1.2876238502833333

# %%
tabelle221 = pandas.read_csv('Daten/reibungebene/Versuch 2 Winkel 2.1.csv')
tabelle222 = pandas.read_csv('Daten/reibungebene/Versuch 2 Winkel 2.2.csv')
tabelle223 = pandas.read_csv('Daten/reibungebene/Versuch 2 Winkel 2.3.csv')
tabelle224 = pandas.read_csv('Daten/reibungebene/Versuch 2 Winkel 2.4.csv')
tabelle225 = pandas.read_csv('Daten/reibungebene/Versuch 2 Winkel 2.5.csv')
tabelle226 = pandas.read_csv('Daten/reibungebene/Versuch 2 Winkel 2.6.csv')

winkel_2 = np.mean([np.mean(tabelle221["Angle (deg)"][0:20]), 
                    np.mean(tabelle222["Angle (deg)"][0:20]), 
                    np.mean(tabelle223["Angle (deg)"][0:20]), 
                    np.mean(tabelle224["Angle (deg)"][0:20]), 
                    np.mean(tabelle225["Angle (deg)"][0:20]), 
                    np.mean(tabelle226["Angle (deg)"][0:20])])

beschleunigung_y2 = (max(tabelle221["Acceleration y (m/s^2)"])-np.mean(tabelle221["Acceleration y (m/s^2)"][0:20]) + 
                     max(tabelle222["Acceleration y (m/s^2)"])-np.mean(tabelle222["Acceleration y (m/s^2)"][0:20]) + 
                     max(tabelle223["Acceleration y (m/s^2)"])-np.mean(tabelle223["Acceleration y (m/s^2)"][0:20]) + 
                     max(tabelle224["Acceleration y (m/s^2)"])-np.mean(tabelle224["Acceleration y (m/s^2)"][0:20]) + 
                     max(tabelle225["Acceleration y (m/s^2)"])-np.mean(tabelle225["Acceleration y (m/s^2)"][0:20]) + 
                     max(tabelle226["Acceleration y (m/s^2)"])-np.mean(tabelle226["Acceleration y (m/s^2)"][0:20]) ) / 6

print('Winkel: ', winkel_2)
print('Beschleunigung in y-Richtung: ', beschleunigung_y2)

plt.plot(tabelle221["Acceleration y (m/s^2)"], alpha = 0.6)
plt.plot(tabelle222["Acceleration y (m/s^2)"], alpha = 0.6)
plt.plot(tabelle223["Acceleration y (m/s^2)"], alpha = 0.6)
plt.plot(tabelle224["Acceleration y (m/s^2)"], alpha = 0.6)
plt.plot(tabelle225["Acceleration y (m/s^2)"], alpha = 0.6)
plt.plot(tabelle226["Acceleration y (m/s^2)"], alpha = 0.6)
# Out:
# Winkel:  20.20529413917884
# Beschleunigung in y-Richtung:  2.377800496458334

# %%
tabelle231 = pandas.read_csv('Daten/reibungebene/Versuch 2 Winkel 3.1.csv')
tabelle232 = pandas.read_csv('Daten/reibungebene/Versuch 2 Winkel 3.2.csv')
tabelle233 = pandas.read_csv('Daten/reibungebene/Versuch 2 Winkel 3.3.csv')
tabelle234 = pandas.read_csv('Daten/reibungebene/Versuch 2 Winkel 3.4.csv')
tabelle235 = pandas.read_csv('Daten/reibungebene/Versuch 2 Winkel 3.5.csv')
tabelle236 = pandas.read_csv('Daten/reibungebene/Versuch 2 Winkel 3.6.csv')

winkel_3 = np.mean([np.mean(tabelle231["Angle (deg)"][0:20]), 
                    np.mean(tabelle232["Angle (deg)"][0:20]), 
                    #np.mean(tabelle233["Angle (deg)"][0:20]), 
                    np.mean(tabelle234["Angle (deg)"][0:20]), 
                    np.mean(tabelle235["Angle (deg)"][0:20]), 
                    np.mean(tabelle236["Angle (deg)"][0:20])])

beschleunigung_y3 = np.mean([max(tabelle231["Acceleration y (m/s^2)"])-np.mean(tabelle231["Acceleration y (m/s^2)"][0:40]),
                             max(tabelle232["Acceleration y (m/s^2)"])-np.mean(tabelle232["Acceleration y (m/s^2)"][0:40]), 
                             # max(tabelle233["Acceleration y (m/s^2)"])-np.mean(tabelle233["Acceleration y (m/s^2)"][0:40]), 
                             max(tabelle234["Acceleration y (m/s^2)"])-np.mean(tabelle234["Acceleration y (m/s^2)"][0:40]), 
                             max(tabelle235["Acceleration y (m/s^2)"])-np.mean(tabelle235["Acceleration y (m/s^2)"][0:40]), 
                             max(tabelle236["Acceleration y (m/s^2)"])-np.mean(tabelle236["Acceleration y (m/s^2)"][0:40])])

print('Winkel: ', winkel_3)
print('Beschleunigung in y-Richtung: ', beschleunigung_y3)

plt.plot(tabelle231["Acceleration y (m/s^2)"], alpha = 0.6)
plt.plot(tabelle232["Acceleration y (m/s^2)"], alpha = 0.6)
# plt.plot(tabelle233["Acceleration y (m/s^2)"], alpha = 0.6)
plt.plot(tabelle234["Acceleration y (m/s^2)"], alpha = 0.6)
plt.plot(tabelle235["Acceleration y (m/s^2)"], alpha = 0.6)
plt.plot(tabelle236["Acceleration y (m/s^2)"], alpha = 0.6)
plt.title('Nicht berücksichtigt!', fontsize = 18)
# Out:
# Winkel:  28.28885011071235
# Beschleunigung in y-Richtung:  20.105646055455004
# Text(0.5, 1.0, 'Nicht berücksichtigt!')

# %%
tabelle241 = pandas.read_csv('Daten/reibungebene/Versuch 2 Winkel 4.1.csv')
tabelle242 = pandas.read_csv('Daten/reibungebene/Versuch 2 Winkel 4.2.csv')
tabelle243 = pandas.read_csv('Daten/reibungebene/Versuch 2 Winkel 4.3.csv')
tabelle244 = pandas.read_csv('Daten/reibungebene/Versuch 2 Winkel 4.4.csv')
tabelle245 = pandas.read_csv('Daten/reibungebene/Versuch 2 Winkel 4.5.csv')
tabelle246 = pandas.read_csv('Daten/reibungebene/Versuch 2 Winkel 4.6.csv')

winkel_4 = np.mean([np.mean(tabelle241["Angle (deg)"][0:10]), 
                    np.mean(tabelle242["Angle (deg)"][0:10]), 
                    np.mean(tabelle243["Angle (deg)"][0:10]), 
                    np.mean(tabelle244["Angle (deg)"][0:10]), 
                    # np.mean(tabelle245["Angle (deg)"][0:20]), 
                    np.mean(tabelle246["Angle (deg)"][0:20])])

beschleunigung_y4 = np.mean([max(tabelle241["Acceleration y (m/s^2)"])-np.mean(tabelle241["Acceleration y (m/s^2)"][0:10]),
                             max(tabelle242["Acceleration y (m/s^2)"])-np.mean(tabelle242["Acceleration y (m/s^2)"][0:10]), 
                             max(tabelle243["Acceleration y (m/s^2)"])-np.mean(tabelle243["Acceleration y (m/s^2)"][0:10]), 
                             max(tabelle244["Acceleration y (m/s^2)"])-np.mean(tabelle244["Acceleration y (m/s^2)"][0:10]), 
                             # max(tabelle245["Acceleration y (m/s^2)"])-np.mean(tabelle245["Acceleration y (m/s^2)"][0:10]), 
                             max(tabelle246["Acceleration y (m/s^2)"])-np.mean(tabelle246["Acceleration y (m/s^2)"][0:10])])

print('Winkel: ', winkel_4)
print('Beschleunigung in y-Richtung: ', beschleunigung_y4)

plt.plot(tabelle241["Acceleration y (m/s^2)"], alpha = 0.6)
plt.plot(tabelle242["Acceleration y (m/s^2)"], alpha = 0.6)
plt.plot(tabelle243["Acceleration y (m/s^2)"], alpha = 0.6)
plt.plot(tabelle244["Acceleration y (m/s^2)"], alpha = 0.6)
# plt.plot(tabelle245["Acceleration y (m/s^2)"], alpha = 0.6)
plt.plot(tabelle246["Acceleration y (m/s^2)"], alpha = 0.6)
plt.title('Nicht berücksichtigt!', fontsize = 18)
# Out:
# Winkel:  31.3514249603521
# Beschleunigung in y-Richtung:  27.15010375856
# Text(0.5, 1.0, 'Nicht berücksichtigt!')

# %% [markdown]
# ---
#
# #### 2.1. Auswertung nach [2], Lineare Regression und Fehlerrechnung

# %%
w = [winkel_1, winkel_2]
b = [beschleunigung_y1 / 9.81, beschleunigung_y2 / 9.81] 

print(w)
print(b)
# Out:
# [16.463505958656285, 20.20529413917884]
# [0.13125625385151204, 0.24238537170829094]

# %%
f = np.linspace(0, 25)
plt.plot(f, 0.0297 * f- 0.3577, 'b--', label = '$\\frac{a_y}{g} = 0,0297\cdot\psi - 0,3577$')
plt.plot(w, b, 'ro')
plt.xlim(0, 25)
plt.ylim(0, 0.5)
plt.xlabel('Winkel der schiefen Ebene: $\psi$ (Grad)', fontsize = 14)
plt.ylabel('Beschleunigung in $y$-Richtung: $a_y / g$', fontsize = 14)
plt.legend(loc = 'upper left', shadow = True, fontsize = 'large')

# %% [markdown]
# \begin{equation}
#     \frac{a_y}{g} = 0,0297\cdot\psi - 0,3577
# \end{equation}
#
# Wenn $a_y/g = 0$ schneidet die Linie die horizontale Achse, und zwar bei $\psi = 12,08^{\textrm{o}}=\arctan(\mu_G)$. Daher ist $\mu_G=\tan(12,08^\textrm{o})=0,2140$.

# %%
ax_mittel_gleit = np.mean(tabelle211["Acceleration x (m/s^2)"][0:20])
ay_mittel_gleit = np.mean(tabelle211["Acceleration y (m/s^2)"][0:20])
az_mittel_gleit = np.mean(tabelle211["Acceleration z (m/s^2)"][0:20])

ax_std_gleit = np.std(tabelle211["Acceleration x (m/s^2)"][0:20], ddof = 1)
ay_std_gleit = np.std(tabelle211["Acceleration y (m/s^2)"][0:20], ddof = 1)
az_std_gleit = np.std(tabelle211["Acceleration z (m/s^2)"][0:20], ddof = 1)

ax_err_gleit = ax_std_gleit / math.sqrt(20)
ay_err_gleit = ay_std_gleit / math.sqrt(20)
az_err_gleit = az_std_gleit / math.sqrt(20)

wahr_fehler_gleit = math.sqrt((((ax_mittel_gleit*ay_mittel_gleit)/(ax_mittel_gleit**2 + az_mittel_gleit**2)**(3/2))*ax_err_gleit)**2 
                                 + ((1/(ax_mittel_gleit**2 + az_mittel_gleit**2)**(1/2))*ay_err_gleit)**2 
                                 + (((ay_mittel_gleit*az_mittel_gleit)/(ax_mittel_gleit**2 + az_mittel_gleit**2)**(3/2))*az_err_gleit)**2 )

# %%
wahr_fehler_gleit
# Out:
# 0.004362960188832452

# %% [markdown]
# **Nach unserer Analyse lässt sich schließlich feststellen, dass $\mu_G\pm\Delta\mu_G = 0,2140 \pm 0,0044$ und $\mu_G < \mu_H$.**

# %% [markdown]
# ---
#
# #### 2.1. Berechnung der Zeitdauer der Beschleunigung
#
# Für die Zeitdauer der Beschleunigung gilt:
#
# \begin{aligned}
#     t\pm \delta t &= \sqrt{\frac{2y}{a_y}} \pm \frac{1}{2}\left(\delta y + \delta a_y\right)\\
#                   &= \sqrt{\frac{2y}{a_y}} \pm \frac{1}{2}\left(\frac{\Delta y}{y} + \frac{\Delta a_y}{a_y}\right).
# \end{aligned}
#
# Hier ist $y=(11\pm 0,1)\textrm{ cm}$ die Verschiebung des Handys auf der schiefen Ebene.

# %%
zeit_wert_1 = math.sqrt((2*11)/ beschleunigung_y1)
zeit_fehler_1 = (1/2)*(0.1/11 + ay_err_gleit/beschleunigung_y1)

print('Zeitdauer (erster Winkel): ', zeit_wert_1)
print('Fehler (erster Winkel): ', zeit_fehler_1)
# Out:
# Zeitdauer (erster Winkel):  4.133489456721734
# Fehler (erster Winkel):  0.01742357566513404

# %%
zeit_wert_2 = math.sqrt((2*11)/ beschleunigung_y2)
zeit_fehler_2 = (1/2)*(0.1/11 + ay_err_gleit/beschleunigung_y2)

print('Zeitdauer (zweiter Winkel): ', zeit_wert_2)
print('Fehler (zweiter Winkel): ', zeit_fehler_2)
# Out:
# Zeitdauer (zweiter Winkel):  3.041750819381023
# Fehler (zweiter Winkel):  0.01151920020882517

# %% [markdown]
# ### Literatur
#
# [1] Gawędzki, W., & Socha, M. (2019). *A Method for the Determination of the Kinetic Friction Coefficient in Friction Pairs Based on Direct Acceleration Measurement of an Object on an Inclined Plane*. Tribologia.
#
# [2] Baldock, C., & Johnson, R. (2016). *Investigation of kinetic friction using an iPhone*. Physics Education, 51(6), 065005.
